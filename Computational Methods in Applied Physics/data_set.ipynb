# %%
import yfinance as yf 

data = yf.download("SPY", start="2015-01-01", end="2022-01-01")
signal = data['Close'].values
signal
# Out:
# [*********************100%***********************]  1 of 1 completed
# array([[170.12503052],
#        [167.05258179],
#        [165.47911072],
#        ...,
#        [450.42755127],
#        [449.18222046],
#        [448.05026245]], shape=(1763, 1))
